# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/packagepredict/data.csv")

# %%
df.head()
# Out:
#          date  zonecode  quantity
# 0  2013-01-01         1       144
# 1  2013-01-02         1       158
# 2  2013-01-03         1       209
# 3  2013-01-04         1      1444
# 4  2013-01-05         1      1323

# %%
df.describe()
# Out:
#            zonecode      quantity
# count  2.071411e+06  2.071411e+06
# mean   5.008620e+02  2.633298e+03
# std    2.886509e+02  2.691117e+03
# min    1.000000e+00  1.000000e+00
# 25%    2.510000e+02  1.009000e+03
# 50%    5.010000e+02  1.856000e+03
# 75%    7.500000e+02  3.346000e+03
# max    1.000000e+03  1.983900e+05

# %%
# 统计查看有多少数据缺失时间 (时间缺失数据如何处理)
# 将日期转化为星期 + 节假日(包括双11)
# 尝试GBDT + XGboost + lightGBM + 随机森林
# 尝试 LSTM ,ARIMA 模型

# %%
zone1 = df[df.zonecode == 1]

# %%
zone1.shape[0]
# Out:
# 2120

# %%
zone1.dtypes
# Out:
# date        object
# zonecode     int64
# quantity     int64
# dtype: object

# %%
import datetime as dt

# %%
ts = df['date']

# %%
ts.head(20).index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
abc = pd.date_range('2013',periods=2)

# %%
abc
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02'], dtype='datetime64[ns]', freq='D')

# %%
from datetime import timedelta
import seaborn as sn

# %%
dt.datetime(2013,1,1) + timedelta(2121)
# Out:
# datetime.datetime(2018, 10, 23, 0, 0)

# %%
# 统计总共多少网点
group = df.groupby(['zonecode'])

# %%
count = group.count()
count.rename(columns={'zonecode':'zonecode','date':'date_count','quanity':'q'},inplace = True)

# %%
group.dtypes
# Out:
#             date quantity
# zonecode
# 1         object    int64
# 2         object    int64
# 3         object    int64
# 4         object    int64
# 5         object    int64
# 6         object    int64
# 7         object    int64
# 8         object    int64
# 9         object    int64
# 10        object    int64
# 11        object    int64
# 12        object    int64
# 13        object    int64
# 14        object    int64
# 15        object    int64
# 16        object    int64
# 17        object    int64
# 18        object    int64
# 19        object    int64
# 20        object    int64
# 21        object    int64
# 22        object    int64
# 23        object    int64
# 24        object    int64
# 25        object    int64
# 26        object    int64
# 27        object    int64
# 28        object    int64
# 29        object    int64
# 30        object    int64
# ...          ...      ...
# 971       object    int64
# 972       object    int64
# 973       object    int64
# ...
